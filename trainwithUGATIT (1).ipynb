# %% [markdown]
# ### Download Data

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !mkdir '/content/data'

# %%
# %cd '/content/data'
# !unzip '/content/gdrive/MyDrive/Colab Notebooks/GANproject/photo2cartoon_resources_20200504.zip'
# Out:
# /content/data
# Archive:  /content/gdrive/MyDrive/Colab Notebooks/GANproject/photo2cartoon_resources_20200504.zip
#    creating: photo2cartoon_resources_20200504/
#    creating: photo2cartoon_resources_20200504/cartoon_data/
#    creating: photo2cartoon_resources_20200504/cartoon_data/testB/
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/194.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/195.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/196.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/197.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/198.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/199.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/200.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/201.png
#   inflating: photo2cartoon_resources_20200504/cartoon_data/testB/202.png
# ...

# %%
# %cd '/content/data'
# !unzip '/content/gdrive/MyDrive/Colab Notebooks/GANproject/All-Age-Faces Dataset.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: All-Age-Faces Dataset/original images/08322A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08323A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08324A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08325A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08326A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08327A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08328A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08329A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08330A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08331A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08332A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08333A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08334A18.jpg
#   inflating: All-Age-Faces Dataset/original images/08335A18.jpg
# ...

# %%
import random

with open("/content/data/All-Age-Faces Dataset/image sets/train.txt", "r") as f:
    traindata = f.read().split('\n')

with open("/content/data/All-Age-Faces Dataset/image sets/val.txt", "r") as f:
    valdata = f.read().split('\n')

traindata_female = [line[:-2] for line in traindata if (line != '' and line[-1] == '0' and int(line[6:8]) >= 17 and int(line[6:8]) <= 30)]
valdata_female = [line[:-2] for line in traindata if (line != '' and line[-1] == '0' and int(line[6:8]) >= 17 and int(line[6:8]) <= 30)]
random.shuffle(traindata_female)
random.shuffle(valdata_female)

# %%
train_data = traindata_female[:1000]
test_data = traindata_female[1000:1200]

# %%
print(len(train_data))
print(len(test_data))
print(test_data)
# Out:
# 1000
# 200
# ...

# %%
# %cd '/content'
# !git clone https://github.com/taki0112/UGATIT.git
# Out:
# /content
# Cloning into 'UGATIT'...
# remote: Enumerating objects: 171, done.
# remote: Total 171 (delta 0), reused 0 (delta 0), pack-reused 171
# Receiving objects: 100% (171/171), 5.68 MiB | 11.58 MiB/s, done.
# Resolving deltas: 100% (89/89), done.

# %%
#!rm -rf '/content/data/photo2cartoon_resources_20200504'

# %%
### move the data to the directory
# !mkdir '/content/UGATIT/face2manhua'
# !mkdir '/content/UGATIT/face2manhua/testA'
# !mkdir '/content/UGATIT/face2manhua/trainA'

# %%
import shutil
shutil.move('/content/data/photo2cartoon_resources_20200504/cartoon_data/testB', '/content/UGATIT/face2manhua') 
shutil.move('/content/data/photo2cartoon_resources_20200504/cartoon_data/trainB', '/content/UGATIT/face2manhua')
# Out:
# '/content/UGATIT/face2manhua/trainB'

# %%
counter = 0
for img in train_data:
  try:
    path = "/content/data/All-Age-Faces Dataset/aglined faces/"+ img
    shutil.move(path, '/content/UGATIT/face2manhua/trainA') 
  except:
    counter+=1
    pass
print(counter)
# Out:
# 0

# %%
import shutil
counter = 0
for img in test_data:
  try:
    path = "/content/data/All-Age-Faces Dataset/aglined faces/"+img
    shutil.move(path, '/content/UGATIT/face2manhua/testA') 
  except:
    counter+=1
    pass
print(counter)
# Out:
# 0

# %%
import os
# %cd '/content/UGATIT/face2manhua/testB'
testBnames = os.listdir()
# %cd '/content/UGATIT/face2manhua/trainB'
trainBnames = os.listdir()

# %cd '/content/UGATIT/face2manhua/testA'
testAnames = os.listdir()
# %cd '/content/UGATIT/face2manhua/trainA'
trainAnames = os.listdir()
# Out:
# /content/UGATIT/face2manhua/testB
# /content/UGATIT/face2manhua/trainB
# /content/UGATIT/face2manhua/testA
# /content/UGATIT/face2manhua/trainA

# %%
# %cd '/content/UGATIT/face2manhua/testB'

for item in testBnames:
  os.rename(item, "test"+item)
# Out:
# /content/UGATIT/face2manhua/testB

# %%
# %cd '/content/UGATIT/face2manhua/trainB'

for item in trainBnames:
  os.rename(item, "train"+item)
# Out:
# /content/UGATIT/face2manhua/trainB

# %%
# %cd '/content/UGATIT/face2manhua/testA'

for item in testAnames:
  os.rename(item, "test"+item)
# Out:
# /content/UGATIT/face2manhua/testA

# %%
# %cd '/content/UGATIT/face2manhua/trainA'

for item in trainAnames:
  os.rename(item, "train"+item)
# Out:
# /content/UGATIT/face2manhua/trainA

# %% [markdown]
# ### Download Model

# %%
# !pip uninstall tensorflow
# Out:
# Found existing installation: tensorflow 2.8.0
# Uninstalling tensorflow-2.8.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
# y
#   Successfully uninstalled tensorflow-2.8.0

# %%
# !pip install tensorboard==1.14.0
# Out:
# ...
#      |████████████████████████████████| 3.1 MB 4.1 MB/s
# ...
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ...

# %%
# !pip install tf-estimator-nightly==2.8.0.dev2021122109
# Out:
# ...
#      |████████████████████████████████| 462 kB 4.3 MB/s
# ...

# %%
# !pip install tensorflow-gpu==1.15
# Out:
# ...
#      |████████████████████████████████| 411.5 MB 7.1 kB/s
# ...
#      |████████████████████████████████| 3.8 MB 70.8 MB/s
# ...
#      |████████████████████████████████| 503 kB 87.4 MB/s
# ...
#      |████████████████████████████████| 50 kB 8.4 MB/s
# ...
#   Created wheel for gast: filename=gast-0.2.2-py3-none-any.whl size=7554 sha256=e779f2f2da1851a2091618fc64b6ecb08fbac2dbd7fb8229cce93bfe0f041577
#   Stored in directory: /root/.cache/pip/wheels/21/7f/02/420f32a803f7d0967b48dd823da3f558c5166991bfd204eef3
# Successfully built gast
# ...
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 1.14.0
#     Uninstalling tensorboard-1.14.0:
#       Successfully uninstalled tensorboard-1.14.0
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
# ...

# %%
'''%cd '/content/UGATIT/checkpoint'

# !unzip '/content/gdrive/MyDrive/Colab Notebooks/GANproject/50_epoch_selfie2anime_checkpoint.zip''''
# Out:
#   File "<ipython-input-24-104e258051b8>", line 3
#     !unzip '/content/gdrive/MyDrive/Colab Notebooks/GANproject/50_epoch_selfie2anime_checkpoint.zip''''
#
# ^
# SyntaxError: EOL while scanning string literal

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase train --light True --epoch 20 --iteration 3000
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [ 0] [ 8593/10000] time: 6302.9308 d_loss: 2.91363811, g_loss: 603.28717041
# Epoch: [ 0] [ 8594/10000] time: 6303.6510 d_loss: 2.14500451, g_loss: 600.48883057
# Epoch: [ 0] [ 8595/10000] time: 6304.3703 d_loss: 2.93890357, g_loss: 735.15869141
# Epoch: [ 0] [ 8596/10000] time: 6305.0918 d_loss: 2.74786735, g_loss: 579.41149902
# Epoch: [ 0] [ 8597/10000] time: 6305.8091 d_loss: 2.47054672, g_loss: 610.09692383
# Epoch: [ 0] [ 8598/10000] time: 6306.5275 d_loss: 2.50748348, g_loss: 1157.91772461
# Epoch: [ 0] [ 8599/10000] time: 6307.2510 d_loss: 2.76883292, g_loss: 668.44293213
# Epoch: [ 0] [ 8600/10000] time: 6307.9797 d_loss: 2.90779185, g_loss: 653.81164551
# Epoch: [ 0] [ 8601/10000] time: 6308.6985 d_loss: 2.18539786, g_loss: 604.92364502
# Epoch: [ 0] [ 8602/10000] time: 6309.4250 d_loss: 2.99650478, g_loss: 744.28417969
# Epoch: [ 0] [ 8603/10000] time: 6310.1420 d_loss: 2.48097491, g_loss: 628.83782959
# ...

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase test --light True
# Out:
# /content/UGATIT
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:88: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From main.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-05-15 01:13:03.476280: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-15 01:13:03.480990: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase train --light True --epoch 20 --iteration 3000
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [ 5] [ 1810/ 3000] time: 2766.8420 d_loss: 1.55093956, g_loss: 176.52282715
# Epoch: [ 5] [ 1811/ 3000] time: 2767.5457 d_loss: 2.23590517, g_loss: 426.94329834
# Epoch: [ 5] [ 1812/ 3000] time: 2768.2529 d_loss: 1.41043139, g_loss: 72.82372284
# Epoch: [ 5] [ 1813/ 3000] time: 2768.9609 d_loss: 1.64962983, g_loss: 93.82732391
# Epoch: [ 5] [ 1814/ 3000] time: 2769.6697 d_loss: 2.05332994, g_loss: 69.53073120
# Epoch: [ 5] [ 1815/ 3000] time: 2770.3770 d_loss: 1.81398678, g_loss: 76.86875916
# Epoch: [ 5] [ 1816/ 3000] time: 2771.0848 d_loss: 1.95802021, g_loss: 109.08918762
# Epoch: [ 5] [ 1817/ 3000] time: 2771.7909 d_loss: 3.20005584, g_loss: 139.12762451
# Epoch: [ 5] [ 1818/ 3000] time: 2772.5001 d_loss: 2.01284790, g_loss: 81.85418701
# Epoch: [ 5] [ 1819/ 3000] time: 2773.2070 d_loss: 1.69860470, g_loss: 99.57262421
# Epoch: [ 5] [ 1820/ 3000] time: 2773.9135 d_loss: 1.64547920, g_loss: 85.92942047
# ...

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase test --light True
# Out:
# /content/UGATIT
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:88: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From main.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-05-15 03:04:17.581823: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-15 03:04:17.586288: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase train --light True --epoch 20 --iteration 10000
# Out:
# Streaming output truncated to the last 5000 lines.
# Epoch: [ 8] [ 5750/10000] time: 45137.2909 d_loss: 1.50426459, g_loss: 10.37040710
# Epoch: [ 8] [ 5751/10000] time: 45138.0035 d_loss: 1.80502880, g_loss: 11.08224487
# Epoch: [ 8] [ 5752/10000] time: 45138.7146 d_loss: 1.99077725, g_loss: 9.66926098
# Epoch: [ 8] [ 5753/10000] time: 45139.4264 d_loss: 2.63424039, g_loss: 11.16206455
# Epoch: [ 8] [ 5754/10000] time: 45140.1378 d_loss: 1.68098831, g_loss: 9.61288929
# Epoch: [ 8] [ 5755/10000] time: 45140.8497 d_loss: 2.60332489, g_loss: 8.90987110
# Epoch: [ 8] [ 5756/10000] time: 45141.5615 d_loss: 3.27760911, g_loss: 11.56743336
# Epoch: [ 8] [ 5757/10000] time: 45142.2729 d_loss: 2.26236987, g_loss: 11.46925354
# Epoch: [ 8] [ 5758/10000] time: 45142.9834 d_loss: 2.24257088, g_loss: 15.33674240
# Epoch: [ 8] [ 5759/10000] time: 45143.7039 d_loss: 2.20766640, g_loss: 146.08445740
# Epoch: [ 8] [ 5760/10000] time: 45144.4160 d_loss: 2.51621985, g_loss: 11.67225456
# ...

# %%
# %cd '/content/UGATIT'
# !python 'main.py' --dataset 'face2manhua' --checkpoint_dir 'checkpoint' --phase test --light True
# Out:
# /content/UGATIT
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.
#
# WARNING:tensorflow:From main.py:88: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# WARNING:tensorflow:From main.py:88: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# 2022-05-15 17:30:26.362084: I tensorflow/core/platform/cpu_feature_guard.cc:142] Your CPU supports instructions that this TensorFlow binary was not compiled to use: AVX2 FMA
# 2022-05-15 17:30:26.367710: I tensorflow/core/platform/profile_utils/cpu_utils.cc:94] CPU Frequency: 2199995000 Hz
# ...
